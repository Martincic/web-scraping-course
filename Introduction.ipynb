# %% [markdown]
# # Introduction into web scraping

# %% [markdown]
# ## HTTP Request
#
# HTTP zahtjev je protokol na principu kojeg danas funkcionira web
#
# HTTP pozivima (requestima) mozemo preuzimati sadrzaj s interneta
#
# HTTP protokol se od
#  - metode (GET, PUT, POST, DELETE, etc.)
#  - destinacije (url ili ip adresa)
#  - headeri (forme, kolacici, tokeni za autorizacije, itd.)
#
# <img src="assets/http-com.png" alt="Image" width="500">
#
#
# ## HTML (Hypertext Markup Language) Dokumenti
#
# U nasem slucaju server ce nam vracati HTML dokumente - u principu to je tree datastructure (document tree)
# <img src="assets/html-tree.png" alt="Image" width="500">
#
# Kad istrazujes, nemoj se zamarati CSS-om, JS-om, nas zanimaju cisti podatci a ne ponasanje i stiliziranje stranice
#
# Sastoji se od raznih "tagova" koji sluze internet preglednicima da prikazuju te informacije na razlicite nacine
#
# Za potrebu obrade podataka, nas ne zanima koji tagovi postoje, vec cemo ih tretirati kao 'noise' u tekstu
#
# HTML dokument je kao bilo koji drugi dokument poput PDF, CSV, .PY, itd. te ima svoj format
#
#
# ### Primjer 1
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>TEXT</title>
#   </head>
#
#   <body>
#     <h1>TEXT2</h1>
#     <p>TEXT3</p>
#   </body>
# </html>
#
# ```
#
# Ako iz ovog primjera zelimo izvuci TEXT2 vrijednost morali bi napraviti sljedece:
#
# - trazimo HMTL tag
# - trazimo child koj se zove "body"
# - u njemu trazimo child koj se zove "h1"
#
#
# ### Primjer 2
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>TEXT</title>
#   </head>
#
#   <body>
#       <list>
#           <item>Auto 1</item>
#           <item>Auto 2</item>
#           <item>Auto 3</item>
#           <item>Auto 4</item>
#       </list>
#   </body>
# </html>
# ```
#
# Ako zelimo iz ovog dokumenta izvuci sve automobile, moramo napraviti sljedece
#  - trazimo element koj se zove list
#  - napravimo petlju za svaki child u tom elementu
#  - for each child write value to database / csv / json
#
#
# ### Primjer 3
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>TEXT</title>
#   </head>
#
#   <body>
#       <div id='list'>
#           <div>Auto 1</div>
#           <div>Auto 2</div>
#           <div>Auto 3</div>
#           <div>Auto 4</div>
#       </div>
#   </body>
# </html>
# ```
#
# Ako zelimo iz ovog dokumenta izvuci sve automobile nemozemo vise traziti element koj se zove div, zato sto ima hrpa div elementa, ali neki elementi sadrze atribute. U ovom slucaju, nasa lista sadrzi atribut koj se zove ID te mozemo elemente pretrazivati i pod atributima.
#
# Ne-pisano pravilo je da je ID element uvijek unikatan u svakom elementu, znaci nemoze postojat vise atributa s jednakom vrjednosti za ID
#
#  - trazimo element koji sadrzi atribut ID s vrjednosti list
#  - napravimo petlju za svaki child u tom elementu
#  - zapisemo u database / csv / json

# %% [markdown]
# ## Primjer HTTP Poziva

# %%
# Import requests library - used to send HTTP requests
import requests


# koristimo requests da posaljemo GET request na zeljeni URL 
url = "https://www.index.hr/oglasi/osobni-automobili/gid/27?elementsNum=100"
response = requests.get(url)

# Isprintat status zahtjeva (200 = OK, 404 = NOT FOUND, 500 = SERVER ERROR, etc.)
display(response)

print("\n Prvih 200 znakova primljenog dokumenta")
display(response.text[:200])
# Out:
# <Response [200]>
#  Prvih 200 znakova primljenog dokumenta
# '<!DOCTYPE html>\r\n<html translate="no">\r\n\t<head>\r\n        <meta charset="utf-8" />\r\n\t\t<meta property="fb:app_id" content="1697489853797759"/>\r\n\r\n\t\t\r\n\r\n\t\t\t<title>Rabljena vozila na prodaju | Auto-moto o'

# %% [markdown]
# ## Prikazati HTML kao sto bi ga preglednik prikazao

# %%
from IPython.display import HTML

display(HTML(response.text))
# Out:
# <!DOCTYPE html>
# <html translate="no">
# 	<head>
#         <meta charset="utf-8" />
# 		<meta property="fb:app_id" content="1697489853797759"/>
#
#
#
# 			<title>Rabljena vozila na prodaju | Auto-moto oglasnik</title>
#
#
# 				<meta property="og:title" content="Rabljena vozila na prodaju | Auto-moto oglasnik"/>
#
#
# 		<meta property="og:url" content="https://www.index.hr/oglasi/osobni-automobili/gid/27?elementsNum=100" />
#
#
# 			<meta name="description" content="Pitate se gdje kupiti auto? Ovo je najveća baza rabljenih automobila u Hrvatskoj! Pretražite oglase, saznajte cijenu i pogledajte slike. – Index Oglasi." />
#
#
#
#
# 		<meta property="og:site_name" content="www.index.hr/oglasi"/>
#
#
#
# 			<meta property="og:image" content="https://www.index.hr/oglasi/img/IndexOglasiLogo.jpg"/>
#
#
#
#
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=3.0, minimum-scale=1.0">
# 		<meta name="format-detection" content="telephone=no" />
#
#         <link rel="SHORTCUT ICON" type="image/ico" href="https://www.index.hr/oglasi/favicon.ico" />
#         <link rel="icon" type="image/png" href="https://www.index.hr/oglasi/favicon.png" />
#
#
#
#
# 		<style>
#
# @charset "UTF-8";.selectator *,html{box-sizing:border-box}ul,ul li{list-style-type:none}.clearfix,.row:after{clear:both}nav,nav a,nav ul a{color:#fff}.btn,.progress{background-clip:padding-box}.btn,.selectator,.selectator *,a{text-decoration:none}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.svg#robotolight) format('svg');font-weight:300;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.svg#robotothin) format('svg');font-weight:400;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.svg#robotobold) format('svg');font-weight:500;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.svg#robotobold) format('svg');font-weight:700;font-style:normal}@font-face{font-family:font-ioglasi;src:url(https://www.index.hr/oglasi/font/ikone/icons5.eot);src:url(https://www.index.hr/oglasi/font/ikone/icons5.eot?#iefix) format("embedded-opentype"),url(https://www.index.hr/oglasi/font/ikone/icons5.woff) format("woff"),url(https://www.index.hr/oglasi/font/ikone/icons5.ttf) format("truetype"),url(https://www.index.hr/oglasi/font/ikone/icons5.svg#font-ioglasi) format("svg");font-weight:400;font-style:normal}[class*=" icon-"]:before,[class^=icon-]:before{font-family:font-ioglasi!important;font-style:normal!important;font-weight:400!important;font-variant:normal!important;text-transform:none!important;speak:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon-auto-moto-menu:before{content:"\66"}.icon-menu:before{content:"\75"}.icon-nekretnine-menu:before{content:"\41"}.icon-plus-mob:before{content:"\43"}.icon-poslovi-menu:before{content:"\45"}.icon-turizam-menu:before{content:"\4c"}.icon-usluge-menu:before{content:"\4f"}.icon-zoom:before{content:"\50"}.icon-arrow-down-menu:before{content:"\62"}.icon-korisnik:before{content:"\73"}.icon-close:before{content:"\51"}.icon-odjeca-menu:before{content:"\23"}.icon-strojevi-menu:before{content:"\24"}.icon-zivotinje-menu:before{content:"\26"}.icon-sve-za-kucu-menu:before{content:"\3d"}.icon-informatika-1-menu:before{content:"\5b"}.icon-stvari-menu:before{content:"\5e"}.icon-foto-menu:before{content:"\60"}.icon-sport-menu:before{content:"\40"}html{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}header,nav{display:block}a{background-color:transparent}img{border:0}button,input,select{color:inherit;font:inherit;m ...

# %%
# Import bs4 library - used to parse HTML and XML documents
from bs4 import BeautifulSoup

# Biblija - https://beautiful-soup-4.readthedocs.io/en/latest/

# Inicijalizirati http parser i predati mu response.text (moze se napravit i xml parser)
# nas dokument je spremljen u memoriji u varijabli response.text !
soup = BeautifulSoup(response.text, "html.parser")

# Prisjetimo se gore Primjera 3, trebamo pronaci element u kojem se nalaze svi automobili
## Za svaki child elementa (svaki auto) stavit u petlju i pisati u file

# Saznati cemo koji element nam treba tako da otvorimo stranicu u web pregledniku
# Desni klik -> inspect element

# nas element ima atribut koj se zove class i ima vrjednost list <div class='list'>
children = soup.find_all("div", class_="OglasiRezHolder")

# Isprintat 3. child
display(children[3])
# Out:
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/mini-cooper-1-6-d/oid/4013931">
# <figure class="result_photo" data-x="2">
# <img alt="MINI Cooper 1.6 d" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2023//5//7/4013931/20230210140702-070520231358072375.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# MINI Cooper 1.6 d
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb"></span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2013
# </li>
# <li>
# km
#  :
# 231.000
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 66
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Grad Zagreb</li>
# <li class="icon-time">Objavljeno prije 9 min</li>
# </ul>
# <span class="price"><span>6.200 €</span> ~ 46.714 kn</span></span>
# </span>
# </a>
# </div>

# %% [markdown]
# # Pronalazak vrijednosti u child elementima
#
# Svaki child element u nasoj listi je poprilicno kompliciran, sadrzi slike, linkove, formatiranje i razno razne tagove (elemente) koji nam nisu korisni
#
# Ovo nebi trebalo bit tesko za procesirat, svaka vrijednost ima unikatni identifikator (title, lead) osim tagova.
#
# Tagovi su zeznuti zato sto nemozemo atribuirat vrijednost po samom tagu, vec moramo pogledati vrijednost taga i procjeniti da li vrijednost sadrzi tekst "godiste" ili "km" te na osnovu toga odluciti gdje pripada taj podatak
#
# ```html
# <div>
#     <a class="result" href="https://www.index.hr/oglasi/bmw-serija-5-530d-automatic/oid/4013168">
#         <div>
#             <span class="title">NAZIV_AUTA</span>
#         </div>
#
#         <span class="lead">OPIS_AUTA</span>
#
#         <ul class="tags">
#             <li>Godiste: 2021</li>
#             <li>km: 20.000</li>
#             <li>Starost: Rabljeno</li>
#             <li>kW: 100</li>
#         </ul>
#
#         <span class='price'>
#             <span>CIJENA_AUTA</span>
#         </span>
#
#         <li class='icon-marker'>::before ZUPANIJA</li>
#     </a>
# </div>
# ```

# %%
import pandas as pd
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Create an empty dataframe with columns
df = pd.DataFrame(columns=["title", "price", "url"])

def findData(child):
    title = child.find("span", class_="title")
    price = child.find("span", class_="price")
    
    if title is not None and price is not None:
        # Extract correct price
        # price.text = "4.499 € ~ 33.898 kn" [4.499,  ~ 33.898 kn]
        euros = price.text.split("€")[0]
        return {"title": title.text, "price": euros, "url": "www.google.com"}

# Za svaki child kreirat podatke i ubacit u dataframe
for child in children:
    row = findData(child)
    df = df.append(row, ignore_index=True)
    
display(df)

# Pisanje podataka u file
df.to_csv('auti.csv')
# Out:
#                                                 title    price             url
# 0                     \r\nPeugeot 307 1.6 HDi\r\n\n\n   1.700   www.google.com
# 1                      \r\nHyundai i30 1.4 GL\r\n\n\n   4.300   www.google.com
# 2                       \r\nMINI Cooper 1.6 d\r\n\n\n   6.200   www.google.com
# 3                    \r\nRenault Clio 1.5 DCI\r\n\n\n   6.200   www.google.com
# 4   \r\nRENAULT MEGANE 1.5DCI //veliki servis//kli...   1.899   www.google.com
# ..                                                ...      ...             ...
# 95  \r\nMercedes-Benz Citan 111 cdi MIXITO, LANG I...   9.900   www.google.com
# 96                     \r\nVW Golf VI 1.6 tdi\r\n\n\n   8.700   www.google.com
# 97          \r\nPeugeot 2008 1.6 e-hdi Allure\r\n\n\n  10.500   www.google.com
# 98              \r\nBMW serija 3 Touring 320d\r\n\n\n   2.250   www.google.com
# 99                    \r\nMINI One 1.4 diesel\r\n\n\n   3.300   www.google.com
#
# [100 rows x 3 columns]

# %% [markdown]
# # Zadaća
#
# ### 1. Zadatak
# Zasad smo kreirali dataframe s nazivom i cijenom
# Treba izvuci sve moguce vrijednosti koje mozemo pronaci za neki auto
#
# Hint: Trebat ce cesto provjeravati da li je vrjednost None, nisu konzistentni podatci
# Hint2: Trebat ce nam i URL da pronadjemo vise podataka o svakom pojedinacnom autu (`<a class="result" href="URL_NA_POJEDINACNI_AUTO">`), kako ces izvaditi atribut?
#
# ### 2. Zadatak
# Ovaj URL ce nam vratit dokument s 1. stranicom automobila s 10 rezultata.
# `url = "https://www.index.hr/oglasi/osobni-automobili/gid/27"`
#
# To je defaultna vrijednost. Neke defaultne vrijednosti web stranica mozemo mijenjati pomocu query parametra u URLu. To saznamo tako da koristimo web stranicu i gledamo kako se URL mijenja. Promjene u URLu su u HTTP protokolu nazvani GET parametri.
#
# Ukoliko dodamo GET parametar `elementsNum=100` onda cemo dobiti natrag 100 rezultata umjesto defaultnih 10.
#
# `url_100_elements = "https://www.index.hr/oglasi/osobni-automobili/gid/27?elementsNum=100"`
#
# Ukoliko dodamo jos jedan parametar `num=2` onda cemo dobiti 2. stranicu s autima
#
# `url_100_elements = "https://www.index.hr/oglasi/osobni-automobili/gid/27?elementsNum=100&num=2"`
#
# Razmisliti kako skinuti podatke s iducih stranica
#
# hint: for petlja
# hint2: counter

# %%
from time import sleep

print(1)

sleep(5)

print(2)
# Out:
# 1
# 2
